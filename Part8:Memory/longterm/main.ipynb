# %%
from crewai import Crew, Agent, Task, Process,LLM
from crewai.memory import LongTermMemory
from crewai.memory.storage.ltm_sqlite_storage import LTMSQLiteStorage

agent_memory_db = "./agent_memory.db"

llm = LLM(model="ollama/llama3.2:1b", temperature=0.7,
          base_url="http://localhost:11434")

storage = LTMSQLiteStorage(db_path=agent_memory_db)

long_term_memory = LongTermMemory(storage=storage)

agent1 = Agent(
    role="A Personal Assistant",
    goal="""You are a personal assistant that can
            help the user with their tasks.""",
    backstory="""You are a personal assistant that
                 can help the user with their tasks.""",
    verbose=True,
    llm=llm
)

task1 = Task(
    description="Handle this task : {user_task}",
    expected_output="Give a clean and concise output",
    agent=agent1
)

crew1 = Crew(
    agents=[agent1],
    tasks=[task1],
    process=Process.sequential,
    memory=True,
    long_term_memory=long_term_memory
)
user_input = {"user_task": "My favourite color is Blue"}

crew1.kickoff(inputs=user_input)

task2 = Task(description="Handle this task: {user_task}",
            expected_output="A clear and concise answer to the question.",
            agent=agent1)

crew2 = Crew(
    agents=[agent1], 
    tasks=[task2], 
    process=Process.sequential,
    memory=True,
    long_term_memory=long_term_memory
)

crew2.kickoff(inputs={"user_task": "What is my favorite color?"})
# Out:
# ERROR:root:Error during short_term search: APIStatusError.__init__() missing 2 required keyword-only arguments: 'response' and 'body'
# ERROR:root:Error during entities search: APIStatusError.__init__() missing 2 required keyword-only arguments: 'response' and 'body'
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: A Personal Assistant                                                                                    │
# │                                                                                                                 │
# │  Task: Handle this task : My favourite color is Blue                                                            │
# │                                                                                                                 │
# ...

# %%
agent2 = Agent(
    role="A Research Assistant",
    goal="""You are a research assistant that can
            help the user with their research tasks.""",
    backstory="""You are a research assistant that
                 can help the user with their research tasks.""",
    verbose=True,
    llm=llm
)

task2 = Task(
    description="Handle this research task : {user_task}",
    expected_output="Give a detailed and well-researched output",
    agent=agent2
)

crew2 = Crew(
    agents=[agent2],
    tasks=[task2],
    process=Process.sequential,
    memory=True,
    long_term_memory=long_term_memory
)
