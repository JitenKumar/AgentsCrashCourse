# %%
# !pip install crewai crewai-tools firecrawl-py
# Out:
# Requirement already satisfied: crewai in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (0.165.1)
# Requirement already satisfied: crewai-tools in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (0.62.3)
# Requirement already satisfied: firecrawl-py in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (3.3.2)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (1.4.4)
# Requirement already satisfied: blinker>=1.9.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (1.9.0)
# Requirement already satisfied: chromadb>=0.5.23 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (0.5.23)
# Requirement already satisfied: click>=8.1.7 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (8.2.1)
# Requirement already satisfied: instructor>=1.3.3 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (1.10.0)
# Requirement already satisfied: json-repair==0.25.2 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (0.25.2)
# Requirement already satisfied: json5>=0.10.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (0.12.1)
# Requirement already satisfied: jsonref>=1.1.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (1.1.0)
# Requirement already satisfied: litellm==1.74.9 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (1.74.9)
# Requirement already satisfied: onnxruntime==1.22.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (1.22.0)
# Requirement already satisfied: openai<1.100.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (1.99.5)
# Requirement already satisfied: openpyxl>=3.1.5 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.30.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (1.36.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.30.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk>=1.30.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (1.36.0)
# Requirement already satisfied: pdfplumber>=0.11.4 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (0.11.7)
# Requirement already satisfied: portalocker==2.7.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (2.7.0)
# Requirement already satisfied: pydantic>=2.4.2 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (2.11.7)
# Requirement already satisfied: pyjwt>=2.9.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (2.10.1)
# Requirement already satisfied: python-dotenv>=1.0.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (1.1.1)
# Requirement already satisfied: pyvis>=0.3.2 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (2025.7.34)
# Requirement already satisfied: tokenizers>=0.20.3 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (0.20.3)
# Requirement already satisfied: tomli-w>=1.1.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai) (0.8.12)
# Requirement already satisfied: aiohttp>=3.10 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from litellm==1.74.9->crewai) (3.12.15)
# Requirement already satisfied: httpx>=0.23.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from litellm==1.74.9->crewai) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from litellm==1.74.9->crewai) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from litellm==1.74.9->crewai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from litellm==1.74.9->crewai) (4.25.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from litellm==1.74.9->crewai) (0.11.0)
# Requirement already satisfied: coloredlogs in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from onnxruntime==1.22.0->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from onnxruntime==1.22.0->crewai) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from onnxruntime==1.22.0->crewai) (2.3.2)
# Requirement already satisfied: packaging in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from onnxruntime==1.22.0->crewai) (25.0)
# Requirement already satisfied: protobuf in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from onnxruntime==1.22.0->crewai) (5.29.5)
# Requirement already satisfied: sympy in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from onnxruntime==1.22.0->crewai) (1.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.74.9->crewai) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.74.9->crewai) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.74.9->crewai) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.74.9->crewai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.74.9->crewai) (0.27.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from openai<1.100.0->crewai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from openai<1.100.0->crewai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from openai<1.100.0->crewai) (0.10.0)
# Requirement already satisfied: sniffio in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from openai<1.100.0->crewai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from openai<1.100.0->crewai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from openai<1.100.0->crewai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<1.100.0->crewai) (3.10)
# Requirement already satisfied: certifi in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from httpx>=0.23.0->litellm==1.74.9->crewai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from httpx>=0.23.0->litellm==1.74.9->crewai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm==1.74.9->crewai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from pydantic>=2.4.2->crewai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from pydantic>=2.4.2->crewai) (0.4.1)
# Requirement already satisfied: docker>=7.1.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai-tools) (7.1.0)
# Requirement already satisfied: embedchain>=0.1.114 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai-tools) (0.1.128)
# Requirement already satisfied: lancedb>=0.5.4 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai-tools) (0.24.3)
# Requirement already satisfied: pyright>=1.1.350 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai-tools) (1.1.403)
# Requirement already satisfied: pytube>=15.0.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai-tools) (15.0.0)
# Requirement already satisfied: requests>=2.31.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai-tools) (2.32.5)
# Requirement already satisfied: stagehand>=0.4.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from crewai-tools) (0.5.1)
# Requirement already satisfied: build>=1.0.3 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (1.3.0)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (0.116.1)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.35.0)
# Requirement already satisfied: posthog>=2.4.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (3.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (1.36.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (0.57b0)
# Requirement already satisfied: pypika>=0.48.9 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (1.74.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (0.16.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (9.1.2)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (3.11.2)
# Requirement already satisfied: rich>=10.11.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from chromadb>=0.5.23->crewai) (13.9.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from tokenizers>=0.20.3->crewai) (0.34.4)
# Requirement already satisfied: filelock in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (2025.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (1.1.8)
# Requirement already satisfied: websockets in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from firecrawl-py) (15.0.1)
# Requirement already satisfied: nest-asyncio in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from firecrawl-py) (1.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from aiohttp>=3.10->litellm==1.74.9->crewai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from aiohttp>=3.10->litellm==1.74.9->crewai) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from aiohttp>=3.10->litellm==1.74.9->crewai) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from aiohttp>=3.10->litellm==1.74.9->crewai) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from aiohttp>=3.10->litellm==1.74.9->crewai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from aiohttp>=3.10->litellm==1.74.9->crewai) (1.20.1)
# Requirement already satisfied: pyproject_hooks in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (1.2.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from docker>=7.1.0->crewai-tools) (2.5.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools) (1.16.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools) (4.13.4)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools) (0.1.44)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.27)
# Requirement already satisfied: langchain-cohere<0.4.0,>=0.3.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.5)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.27)
# Requirement already satisfied: langchain-openai<0.3.0,>=0.2.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools) (0.2.14)
# Requirement already satisfied: langsmith<0.4.0,>=0.3.18 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.45)
# Requirement already satisfied: mem0ai<0.2.0,>=0.1.54 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools) (0.1.116)
# Requirement already satisfied: pypdf<6.0.0,>=5.0.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools) (5.9.0)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools) (0.7.7)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools) (2.0.43)
# Requirement already satisfied: Mako in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai-tools) (1.3.10)
# Requirement already satisfied: soupsieve>1.2 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain>=0.1.114->crewai-tools) (2.7)
# Requirement already satisfied: cachetools in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from gptcache<0.2.0,>=0.1.43->embedchain>=0.1.114->crewai-tools) (5.5.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.3.74)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.3.9)
# Requirement already satisfied: cohere<6.0,>=5.5.6 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (5.17.0)
# Requirement already satisfied: langchain-experimental<0.4.0,>=0.3.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (0.3.4)
# Requirement already satisfied: pandas>=1.4.3 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (2.3.1)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (0.9.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (1.12.0)
# Requirement already satisfied: httpx-sse==0.4.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (0.4.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (2.32.4.20250809)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (2.10.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai-tools) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai-tools) (0.23.0)
# Requirement already satisfied: pytz>=2024.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (2025.2)
# Requirement already satisfied: qdrant-client>=1.9.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (1.15.1)
# Requirement already satisfied: six>=1.5 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (1.17.0)
# Requirement already satisfied: monotonic>=1.5 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from requests>=2.31.0->crewai-tools) (3.4.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (2.19.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (1.1.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb>=0.5.23->crewai) (0.47.2)
# Requirement already satisfied: zipp>=3.20 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from importlib-metadata>=6.8.0->litellm==1.74.9->crewai) (3.23.0)
# Requirement already satisfied: diskcache>=5.6.3 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from instructor>=1.3.3->crewai) (5.6.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from instructor>=1.3.3->crewai) (0.17.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai) (1.5.4)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.6.1)
# Requirement already satisfied: deprecation in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from lancedb>=0.5.4->crewai-tools) (2.1.0)
# Requirement already satisfied: pyarrow>=16 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from lancedb>=0.5.4->crewai-tools) (21.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.2)
# Requirement already satisfied: et-xmlfile in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.36.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.36.0)
# Requirement already satisfied: opentelemetry-proto==1.36.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.36.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from opentelemetry-sdk>=1.30.0->crewai) (0.57b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.57b0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.57b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.57b0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.57b0)
# Requirement already satisfied: opentelemetry-util-http==0.57b0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.57b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.57b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (1.17.3)
# Requirement already satisfied: asgiref~=3.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.57b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (3.9.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (2025.2)
# Requirement already satisfied: pdfminer.six==20250506 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from pdfplumber>=0.11.4->crewai) (20250506)
# Requirement already satisfied: Pillow>=9.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from pdfplumber>=0.11.4->crewai) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from pdfplumber>=0.11.4->crewai) (4.30.0)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (45.0.6)
# Requirement already satisfied: cffi>=1.14 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (1.17.1)
# Requirement already satisfied: pycparser in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (2.22)
# Requirement already satisfied: nodeenv>=1.6.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from pyright>=1.1.350->crewai-tools) (1.9.1)
# Requirement already satisfied: ipython>=5.3.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from pyvis>=0.3.2->crewai) (9.4.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from pyvis>=0.3.2->crewai) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from pyvis>=0.3.2->crewai) (3.5)
# Requirement already satisfied: decorator in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.51)
# Requirement already satisfied: stack_data in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Requirement already satisfied: wcwidth in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.0)
# Requirement already satisfied: h2<5,>=3 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (4.2.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (4.1.0)
# Requirement already satisfied: playwright>=1.42.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from stagehand>=0.4.1->crewai-tools) (1.54.0)
# Requirement already satisfied: browserbase>=1.4.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from stagehand>=0.4.1->crewai-tools) (1.4.0)
# Requirement already satisfied: anthropic>=0.51.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from stagehand>=0.4.1->crewai-tools) (0.64.0)
# Requirement already satisfied: pyee<14,>=13 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from playwright>=1.42.1->stagehand>=0.4.1->crewai-tools) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from playwright>=1.42.1->stagehand>=0.4.1->crewai-tools) (3.2.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from coloredlogs->onnxruntime==1.22.0->crewai) (10.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/B0224761/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages (from sympy->onnxruntime==1.22.0->crewai) (1.3.0)

# %%
from crewai import LLM

llm = LLM(model="ollama/llama3.2",
          base_url="http://localhost:11434")

# %%
import yaml

with open('config/planner_agents.yaml','r') as f:
    agents_config = yaml.safe_load(f)

with open('config/planner_tasks.yaml','r') as f:
    tasks_config = yaml.safe_load(f)

# %%
from pydantic import BaseModel
from typing import Optional

class Tweet(BaseModel):
    """Reprsents and individual tweet in a thread"""
    content: str
    is_hook: bool = False
    media_urls: Optional[list[str]] = []

class Thread(BaseModel):
    """Represents a Twitter thread"""
    topic: str
    tweets: list[Tweet] = []

# %%
from pydantic import BaseModel
from typing import Optional

class LinkedInPost(BaseModel):
    """Represents a LinkedIn post"""
    content: str
    media_urls: str

# %%
from crewai_tools import DirectoryReadTool, FileReadTool

all_tools = [DirectoryReadTool, FileReadTool]

# %%
from crewai import Agent, Task

draft_analyzer = Agent(config=agents_config['draft_analyzer'],tools=all_tools,llm=llm)
analyze_draft_task = Task(config=tasks_config['analyze_draft'],agent=draft_analyzer)

twitter_thread_planner = Agent(config=agents_config['twitter_thread_planner'],tools=all_tools,llm=llm)
create_twitter_thread_plan = Task(config=tasks_config['create_twitter_thread_plan'],agent=twitter_thread_planner,output_pydantic=Thread)


linked_post_planner = Agent(config=agents_config['linkedin_post_planner'],tools=all_tools,llm=llm)
create_linkedin_post_plan = Task(config=tasks_config['create_linkedin_post_plan'],agent=linked_post_planner,output_pydantic=LinkedInPost)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[10], line 3
#       1 from crewai import Agent, Task
# ----> 3 draft_analyzer = Agent(config=agents_config['draft_analyzer'],tools=all_tools,llm=llm)
#       4 analyze_draft_task = Task(config=tasks_config['analyze_draft'],agent=draft_analyzer)
#       6 twitter_thread_planner = Agent(config=agents_config['twitter_thread_planner'],tools=all_tools,llm=llm)
#
# File ~/airtel_b0224761/CodeWorkspace/AI/AgentsCrashCourse/.venv/lib/python3.11/site-packages/pydantic/main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
#     257         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     258         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     259         stacklevel=2,
#     260     )
#
# ValidationError: 2 validation errors for Agent
# tools.0
#   Input should be a valid dictionary or instance of BaseTool [type=model_type, input_value=<class 'crewai_tools.tool...tool.DirectoryReadTool'>, input_type=ModelMetaclass]
#     For further information visit https://errors.pydantic.dev/2.11/v/model_type
# tools.1
#   Input should be a valid dictionary or instance of BaseTool [type=model_type, input_value=<class 'crewai_tools.tool...read_tool.FileReadTool'>, input_type=ModelMetaclass]
#     For further information visit https://errors.pydantic.dev/2.11/v/model_type

# %%
from pydantic import BaseModel
from pathlib import Path

class ContentPlanningState(BaseModel):
    """
    State for the content planning flow
    """
    # URL of the blog to scrape
    blog_post_url: str = blog_post_url
    
    # Path where the scraped content will be stored
    draft_path: Path = "assets/"
    
    # Determines whether to create a Twitter or LinkedIn post 
    post_type: str = "twitter"  
    
    # Example Twitter threads for style reference
    path_to_example_threads: str = "assets/example_threads.txt" 
    
    # Example LinkedIn posts for reference
    path_to_example_linkedin: str = "assets/example_linkedin.txt"

# %%
from firecrawl import FirecrawlApp
import os
import uuid

class CreateContentPlanningFlow(Flow[ContentPlanningState]):

    @start()
    def scrape_blog_post(self):
        print(f"# Fetching draft from: {self.state.blog_post_url}")

        # Initialize FireCrawl
        app = FirecrawlApp(api_key=os.getenv("FIRECRAWL_API_KEY"))
        
        # Scrape the blog post in Markdown and HTML format
        scrape_result = app.scrape_url(self.state.blog_post_url,
                                       params={'formats': ['markdown', 'html']})

        # Extract the title (fallback to a UUID if not found)
        try:
            title = scrape_result['metadata']['title']
        except Exception:
            title = str(uuid.uuid4())

        # Store the scraped content as a markdown file
        self.state.draft_path = f'assets/{title}.md'
        with open(self.state.draft_path, 'w') as f:
            f.write(scrape_result['markdown'])

        return self.state
    
    @router(scrape_blog_post)
    def select_platform(self):
        if self.state.post_type == "twitter":
            return "twitter"
        elif self.state.post_type == "linkedin":
            return "linkedin"
        
    @listen("twitter")
    def twitter_draft(self):
        print(f"planning Twitter post for : {self.state.draft_path}")
        result = twitter_planning_crew,kickoff(inputs={
            "draft_path": str(self.state.draft_path),
            "path_to_example_threads": self.state.path_to_example_threads
        })
        print(f"#Planned Twitter post for {self.state.draft_path}")

        for i,tweet in enumerate(result.pydantic.tweets):
            print(f"Tweet {i+1}: {tweet.content}\n")
            print(f"Media Urls: {tweet.media_urls}\n")
            print("-"*100)

        return result
    
    @listen("linkedin")
    def linkedin_draft(self):
        print(f"# Planning content for: {self.state.draft_path}")
    
        # Execute the LinkedIn Planning Crew
        result = linkedin_planning_crew.kickoff(inputs={
            'draft_path': self.state.draft_path, 
            'path_to_example_linkedin': self.state.path_to_example_linkedin
        })
    
        print(f"# Planned content for {self.state.draft_path}:")
        print(f"{result.pydantic.content}")
    
        return result

    @listen(or_(twitter_draft, linkedin_draft))
    def save_plan(self,plan):
        with open(f"output/draft.json", 'w') as f:
            json.dump(plan.pydantic.model_dump(), f, indent=2)



flow = CreateContentPlanningFlow()
flow.plot()
flow.kickoff()
blog_post_url = "https://blog.dailydoseofds.com/p/5-chunking-strategies-for-rag"
draft_path = "assets/"
post_type = "twitter"
path_to_example_threads = "assets/example_threads.txt"
path_to_example_linkedin = "assets/example_linkedin.txt"
flow.state.post_type = "linkedin"
flow.kickoff()

# %%
cd /book_flow
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 cd /book_flow
#
# NameError: name 'cd' is not defined
